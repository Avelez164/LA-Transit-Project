# %% [markdown]
# <a href="https://colab.research.google.com/github/Avelez164/LA-Transit-Project/blob/main/LA_Transit_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# URL of Wikipedia page
url = "https://en.wikipedia.org/wiki/Los_Angeles_Metro_Rail#Ridership"

# Read all tables on the page
tables = pd.read_html(url)

# Check how many tables were extracted
print(f"Total tables extracted: {len(tables)}")

# Display the first few rows of the likely ridership table
tables[0].head()
# Out:
# Total tables extracted: 47
#                                           Metro Rail  \
# 0  Metro Rail rapid transit (subway) B Line train...
# 1         Metro Rail light rail E Line train in 2023
# 2                                           Overview
# 3                                        Area served
# 4                                       Transit type
#
#                                         Metro Rail.1 Unnamed: 2 Unnamed: 3  \
# 0  Metro Rail rapid transit (subway) B Line train...        NaN        NaN
# 1         Metro Rail light rail E Line train in 2023        NaN        NaN
# 2                                           Overview        NaN        NaN
# 3                     Los Angeles County, California        NaN        NaN
# 4                   Light railRapid transit (subway)        NaN        NaN
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6
# 0        NaN        NaN        NaN
# 1        NaN        NaN        NaN
# 2        NaN        NaN        NaN
# ...
